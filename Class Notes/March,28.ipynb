# %% [markdown]
# #### Pattern in Python
# <a id ="pattern"></a>

# %%
# rows = int(input("Ente the no. of rows: "))
# cols = int(input("Entr the no. of cols: "))
# for i in range(rows):
#     for j in range(cols):
#         print("#", end=" ")
#     print("")


## diagonal 

# rows = int(input("Ente the no. of rows: "))
# cols = int(input("Entr the no. of cols: "))
# for i in range(rows):
#     for j in range(cols):
#         if i == j:
#             print("*", end = " ")
#         else:
#             print(" ", end= " ")
    
#     print("")
    

## upper j > i and lower i > j triangle

# rows = int(input("Ente the no. of rows: "))
# cols = int(input("Entr the no. of cols: "))
# for i in range(rows):
#     for j in range(cols):
#         if i ==j :
#             print("*", end=" ")
#         elif i > j :
#             print("#", end = " ")
#         else:
#             print("@", end = " ")
#     print("")

## reverse ro right to left diagnoal is i+j == no . of rows +1
    
# rows = int(input("Ente the no. of rows: "))
# cols = int(input("Entr the no. of cols: "))
# for i in range(rows):
#     for j in range(cols):
#         if i+j == rows - 1:
#             print("*", end = " ")
        
#         else:
#             print(" ", end= " ")
    
#     print("")    


## for reverse or sencindary diagonal lower tra = i+j > r+1  anf upper trainge i+j < r+1

# rows = int(input("Ente the no. of rows: "))
# cols = int(input("Entr the no. of cols: "))
# for i in range(rows):
#     for j in range(cols):
#         if i+j == rows - 1:
#             print("#", end = " ")
#         elif i+j < rows-1:
#             print("*", end = " ")
#         else:
#             print("@", end= " ")
    
#     print("")    


## question 

rows = int(input("Ente the no. of rows: "))
cols = int(input("Entr the no. of cols: "))
for i in range(rows):
    for j in range(cols):
        if i+j == 0:
            print("*", end = " ")
        elif i+j == rows-1:
            print("#", end = " ")
        
        elif i+j == (rows-1)*2:
            print("@", end =" ")
        else:
            print(" ", end =" ")
           
    
    print("")
# Out:
# *     #
#     #
#   #
# #     @
